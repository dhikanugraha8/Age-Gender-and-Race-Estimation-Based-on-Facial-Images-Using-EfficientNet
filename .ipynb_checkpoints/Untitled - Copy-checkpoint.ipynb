# %%
import tensorflow as tf
import os
import re
import random
from tensorflow.keras import layers

# Path to the dataset
dataset_path = 'dataset'
image_size = (200, 200)
batch_size = 32

# Regular expression to parse the filename
pattern = r"(\d+)_(\d)_(\d)_(\d+).jpg"

# Function to parse the label from the filename
def parse_label(filename):
    match = re.match(pattern, filename)
    if match:
        age = int(match.group(1))
        gender = int(match.group(2))
        return age, gender
    else:
        raise ValueError(f"Filename {filename} does not match the format")

# Function to load image and label
def load_image(filename, label):
    image = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, image_size)
    image = tf.cast(image, tf.float32) / 255.0
    
    age, gender = label
    return image, (age, gender)

# Function to create a dataset from image files
def create_dataset(image_files):
    labels = [parse_label(os.path.basename(file)) for file in image_files]
    ages = tf.constant([label[0] for label in labels], dtype=tf.int32)
    genders = tf.constant([label[1] for label in labels], dtype=tf.int32)

    dataset = tf.data.Dataset.from_tensor_slices((image_files, (ages, genders)))
    dataset = dataset.map(lambda x, y: (load_image(x, y)), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
# Get all image files
all_files = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if f.endswith('.jpg')]
total_files = len(all_files)

# Shuffle files with a consistent seed
seed = 42
random.seed(seed)
random.shuffle(all_files)

# Split the data into train, validation, and test
train_split = 0.7
val_split = 0.15
test_split = 0.15

train_count = int(total_files * train_split)
val_count = int(total_files * val_split)

train_files = all_files[:train_count]
val_files = all_files[train_count:train_count + val_count]
test_files = all_files[train_count + val_count:]

# Create dataset for each subset
train_ds = create_dataset(train_files)
val_ds = create_dataset(val_files)
test_ds = create_dataset(test_files)

# %%
import matplotlib.pyplot as plt

# Function to show image samples and labels for age and gender
def show_image_samples(dataset, subset_name, num_samples=5):
    plt.figure(figsize=(20, 6))  # Increase image size
    gender_map = {0: 'Male', 1: 'Female'}  # Mapping for gender labels
    
    for images, (ages, genders) in dataset.take(1):  # Take the first batch from the dataset
        for j in range(num_samples):
            ax = plt.subplot(1, num_samples, j + 1)  # 1 row, num_samples columns
            plt.imshow(images[j].numpy())  # Display the image
            age = ages[j].numpy()
            gender = genders[j].numpy()
            plt.title(f"Age: {age}, Gender: {gender_map[gender]}", fontsize=75/num_samples)  # Display the age and gender
            plt.axis("off")  # Hide the axes
    
    plt.suptitle(f"{subset_name} Samples", fontsize=20)  # Title for each subset
    plt.show()
    print('\n')

# Display some image samples and labels from each subset
show_image_samples(train_ds, "Training", 5)
show_image_samples(val_ds, "Validation")
show_image_samples(test_ds, "Testing")

# %%
import matplotlib.pyplot as plt

# Function to plot the age distribution
def plot_age_distribution(dataset, subset_name):
    ages = []
    
    # Extract all ages from the dataset
    for _, (age_labels, _) in dataset:
        ages.extend(age_labels.numpy())
    
    # Plot the histogram
    plt.figure(figsize=(10, 6))
    plt.hist(ages, bins=range(0, 120, 5), edgecolor='black')  # Binning ages in groups of 5
    plt.title(f"Age Distribution in {subset_name} Set")
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.show()

# Plot age distribution for training, validation, and test sets
plot_age_distribution(train_ds, "Training")
plot_age_distribution(val_ds, "Validation")
plot_age_distribution(test_ds, "Testing")

# %%
import numpy as np

# Function to plot the gender distribution
def plot_gender_distribution(dataset, subset_name):
    gender_count = {0: 0, 1: 0}  # 0 for Male, 1 for Female
    
    # Extract all genders from the dataset
    for _, (_, gender_labels) in dataset:
        unique, counts = np.unique(gender_labels.numpy(), return_counts=True)
        for u, c in zip(unique, counts):
            gender_count[u] += c
    
    # Plot the bar chart
    plt.figure(figsize=(6, 4))
    plt.bar(['Male', 'Female'], [gender_count[0], gender_count[1]], color=['blue', 'pink'])
    plt.title(f"Gender Distribution in {subset_name} Set")
    plt.xlabel("Gender")
    plt.ylabel("Count")
    plt.show()

# Plot gender distribution for training, validation, and test sets
plot_gender_distribution(train_ds, "Training")
plot_gender_distribution(val_ds, "Validation")
plot_gender_distribution(test_ds, "Testing")

# %%
from tensorflow.keras import layers

# Data augmentation layer
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1)
])

# %%
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# Create Model
input_shape = (200, 200, 3)  # sesuai input shape
inputs = Input(input_shape)

# Convolutional layers
inputs = Input(shape=input_shape)
x = data_augmentation(inputs)  # Augmentasi di dalam arsitektur
x = layers.Conv2D(32, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(256, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Flatten()(x)

# Dense layers for each output
dense_age = layers.Dense(256, activation='relu')(x)
dropout_age = layers.Dropout(0.3)(dense_age)
age = layers.Dense(1, activation='relu', name='age')(dropout_age)

dense_gender = layers.Dense(256, activation='relu')(x)
dropout_gender = layers.Dropout(0.3)(dense_gender)
gender = layers.Dense(1, activation='sigmoid', name='gender')(dropout_gender)

# Model with two outputs
model = models.Model(inputs=inputs, outputs=[age,gender])

# %%
# Compile the model
model.compile(
    optimizer='adam',
    loss={'age': 'mae', 'gender': 'binary_crossentropy'},
    metrics={'age': 'mae','gender': 'accuracy'}
)

# %%
model.summary()
# Out:
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_20 (InputLayer)          [(None, 200, 200, 3  0           []
#                                 )]
#
#  sequential_3 (Sequential)      (None, 200, 200, 3)  0           ['input_20[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 198, 198, 32  896         ['sequential_3[4][0]']
#                                 )
#
#  max_pooling2d_52 (MaxPooling2D  (None, 99, 99, 32)  0           ['conv2d_52[0][0]']
#  )
#
#  conv2d_53 (Conv2D)             (None, 97, 97, 64)   18496       ['max_pooling2d_52[0][0]']
#
#  max_pooling2d_53 (MaxPooling2D  (None, 48, 48, 64)  0           ['conv2d_53[0][0]']
#  )
#
#  conv2d_54 (Conv2D)             (None, 46, 46, 128)  73856       ['max_pooling2d_53[0][0]']
#
#  max_pooling2d_54 (MaxPooling2D  (None, 23, 23, 128)  0          ['conv2d_54[0][0]']
#  )
#
#  conv2d_55 (Conv2D)             (None, 21, 21, 256)  295168      ['max_pooling2d_54[0][0]']
#
#  max_pooling2d_55 (MaxPooling2D  (None, 10, 10, 256)  0          ['conv2d_55[0][0]']
#  )
#
#  flatten_13 (Flatten)           (None, 25600)        0           ['max_pooling2d_55[0][0]']
#
#  dense_23 (Dense)               (None, 256)          6553856     ['flatten_13[0][0]']
#
#  dense_24 (Dense)               (None, 256)          6553856     ['flatten_13[0][0]']
#
#  dropout_23 (Dropout)           (None, 256)          0           ['dense_23[0][0]']
#
#  dropout_24 (Dropout)           (None, 256)          0           ['dense_24[0][0]']
#
#  age (Dense)                    (None, 1)            257         ['dropout_23[0][0]']
#
#  gender (Dense)                 (None, 1)            257         ['dropout_24[0][0]']
#
# ==================================================================================================
# Total params: 13,496,642
# Trainable params: 13,496,642
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Early Stopping
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5,          
    restore_best_weights=True 
)

# Model fitting
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# 173/173 [==============================] - 540s 3s/step - loss: 23.2311 - age_loss: 22.4950 - gender_loss: 0.7361 - age_mae: 22.4950 - gender_accuracy: 0.5404 - val_loss: 20.4389 - val_age_loss: 19.7474 - val_gender_loss: 0.6915 - val_age_mae: 19.7474 - val_gender_accuracy: 0.5300
# Epoch 2/30
# 173/173 [==============================] - 575s 3s/step - loss: 20.9949 - age_loss: 20.3375 - gender_loss: 0.6573 - age_mae: 20.3375 - gender_accuracy: 0.6045 - val_loss: 17.9384 - val_age_loss: 17.2979 - val_gender_loss: 0.6406 - val_age_mae: 17.2979 - val_gender_accuracy: 0.6762
# Epoch 3/30
# 173/173 [==============================] - 592s 3s/step - loss: 18.8306 - age_loss: 18.2091 - gender_loss: 0.6216 - age_mae: 18.2091 - gender_accuracy: 0.6590 - val_loss: 15.8713 - val_age_loss: 15.2868 - val_gender_loss: 0.5845 - val_age_mae: 15.2868 - val_gender_accuracy: 0.7041
# Epoch 4/30
# 173/173 [==============================] - 581s 3s/step - loss: 17.2819 - age_loss: 16.6957 - gender_loss: 0.5862 - age_mae: 16.6957 - gender_accuracy: 0.6905 - val_loss: 16.4173 - val_age_loss: 15.8412 - val_gender_loss: 0.5761 - val_age_mae: 15.8412 - val_gender_accuracy: 0.6999
# Epoch 5/30
# 173/173 [==============================] - 577s 3s/step - loss: 16.4913 - age_loss: 15.9257 - gender_loss: 0.5655 - age_mae: 15.9257 - gender_accuracy: 0.7130 - val_loss: 15.9966 - val_age_loss: 15.4415 - val_gender_loss: 0.5551 - val_age_mae: 15.4415 - val_gender_accuracy: 0.7126
# Epoch 6/30
# 173/173 [==============================] - 601s 3s/step - loss: 15.6942 - age_loss: 15.1374 - gender_loss: 0.5569 - age_mae: 15.1374 - gender_accuracy: 0.7050 - val_loss: 13.9739 - val_age_loss: 13.4493 - val_gender_loss: 0.5246 - val_age_mae: 13.4493 - val_gender_accuracy: 0.7456
# Epoch 7/30
# 173/173 [==============================] - 519s 3s/step - loss: 14.9224 - age_loss: 14.3902 - gender_loss: 0.5322 - age_mae: 14.3902 - gender_accuracy: 0.7378 - val_loss: 13.9931 - val_age_loss: 13.4991 - val_gender_loss: 0.4941 - val_age_mae: 13.4991 - val_gender_accuracy: 0.7523
# Epoch 8/30
# 173/173 [==============================] - 507s 3s/step - loss: 14.3040 - age_loss: 13.7778 - gender_loss: 0.5263 - age_mae: 13.7778 - gender_accuracy: 0.7385 - val_loss: 12.9984 - val_age_loss: 12.5175 - val_gender_loss: 0.4809 - val_age_mae: 12.5175 - val_gender_accuracy: 0.7557
# Epoch 9/30
# 173/173 [==============================] - 519s 3s/step - loss: 13.7337 - age_loss: 13.2246 - gender_loss: 0.5090 - age_mae: 13.2246 - gender_accuracy: 0.7535 - val_loss: 12.3720 - val_age_loss: 11.9078 - val_gender_loss: 0.4642 - val_age_mae: 11.9078 - val_gender_accuracy: 0.7828
# Epoch 10/30
# 173/173 [==============================] - 493s 3s/step - loss: 13.0841 - age_loss: 12.5869 - gender_loss: 0.4972 - age_mae: 12.5869 - gender_accuracy: 0.7631 - val_loss: 11.9024 - val_age_loss: 11.4393 - val_gender_loss: 0.4630 - val_age_mae: 11.4393 - val_gender_accuracy: 0.7887
# Epoch 11/30
# 173/173 [==============================] - 479s 3s/step - loss: 13.0008 - age_loss: 12.5077 - gender_loss: 0.4931 - age_mae: 12.5077 - gender_accuracy: 0.7651 - val_loss: 11.0522 - val_age_loss: 10.6009 - val_gender_loss: 0.4512 - val_age_mae: 10.6009 - val_gender_accuracy: 0.7937
# Epoch 12/30
# 173/173 [==============================] - 508s 3s/step - loss: 12.2936 - age_loss: 11.8171 - gender_loss: 0.4765 - age_mae: 11.8171 - gender_accuracy: 0.7669 - val_loss: 10.5412 - val_age_loss: 10.1015 - val_gender_loss: 0.4398 - val_age_mae: 10.1015 - val_gender_accuracy: 0.7980
# Epoch 13/30
# 173/173 [==============================] - 502s 3s/step - loss: 11.8339 - age_loss: 11.3811 - gender_loss: 0.4529 - age_mae: 11.3811 - gender_accuracy: 0.7749 - val_loss: 10.4503 - val_age_loss: 10.0237 - val_gender_loss: 0.4266 - val_age_mae: 10.0237 - val_gender_accuracy: 0.8014
# Epoch 14/30
# 173/173 [==============================] - 494s 3s/step - loss: 11.6724 - age_loss: 11.2191 - gender_loss: 0.4533 - age_mae: 11.2191 - gender_accuracy: 0.7858 - val_loss: 10.2981 - val_age_loss: 9.8772 - val_gender_loss: 0.4209 - val_age_mae: 9.8772 - val_gender_accuracy: 0.8022
# Epoch 15/30
# 173/173 [==============================] - 493s 3s/step - loss: 11.4175 - age_loss: 10.9718 - gender_loss: 0.4458 - age_mae: 10.9718 - gender_accuracy: 0.7861 - val_loss: 10.4208 - val_age_loss: 9.9833 - val_gender_loss: 0.4375 - val_age_mae: 9.9833 - val_gender_accuracy: 0.7887
# Epoch 16/30
# 173/173 [==============================] - 529s 3s/step - loss: 11.1615 - age_loss: 10.7263 - gender_loss: 0.4352 - age_mae: 10.7263 - gender_accuracy: 0.7983 - val_loss: 10.3201 - val_age_loss: 9.9029 - val_gender_loss: 0.4172 - val_age_mae: 9.9029 - val_gender_accuracy: 0.8064
# Epoch 17/30
# 173/173 [==============================] - 482s 3s/step - loss: 11.1458 - age_loss: 10.7096 - gender_loss: 0.4362 - age_mae: 10.7096 - gender_accuracy: 0.7972 - val_loss: 9.5751 - val_age_loss: 9.1822 - val_gender_loss: 0.3929 - val_age_mae: 9.1822 - val_gender_accuracy: 0.8166
# Epoch 18/30
# 173/173 [==============================] - 509s 3s/step - loss: 10.7852 - age_loss: 10.3555 - gender_loss: 0.4297 - age_mae: 10.3555 - gender_accuracy: 0.7948 - val_loss: 10.6095 - val_age_loss: 10.2216 - val_gender_loss: 0.3879 - val_age_mae: 10.2216 - val_gender_accuracy: 0.8132
# Epoch 19/30
# 173/173 [==============================] - 502s 3s/step - loss: 10.5222 - age_loss: 10.1096 - gender_loss: 0.4126 - age_mae: 10.1096 - gender_accuracy: 0.8053 - val_loss: 9.7860 - val_age_loss: 9.3922 - val_gender_loss: 0.3938 - val_age_mae: 9.3922 - val_gender_accuracy: 0.8335
# Epoch 20/30
# 173/173 [==============================] - 495s 3s/step - loss: 10.4851 - age_loss: 10.0736 - gender_loss: 0.4116 - age_mae: 10.0736 - gender_accuracy: 0.8095 - val_loss: 10.0034 - val_age_loss: 9.5675 - val_gender_loss: 0.4359 - val_age_mae: 9.5675 - val_gender_accuracy: 0.7836
# Epoch 21/30
# 173/173 [==============================] - 489s 3s/step - loss: 10.3134 - age_loss: 9.9043 - gender_loss: 0.4091 - age_mae: 9.9043 - gender_accuracy: 0.8124 - val_loss: 9.1658 - val_age_loss: 8.7941 - val_gender_loss: 0.3717 - val_age_mae: 8.7941 - val_gender_accuracy: 0.8428
# Epoch 22/30
# 173/173 [==============================] - 486s 3s/step - loss: 10.3176 - age_loss: 9.9220 - gender_loss: 0.3956 - age_mae: 9.9220 - gender_accuracy: 0.8205 - val_loss: 9.4177 - val_age_loss: 9.0498 - val_gender_loss: 0.3680 - val_age_mae: 9.0498 - val_gender_accuracy: 0.8385
# Epoch 23/30
# 173/173 [==============================] - 482s 3s/step - loss: 10.2781 - age_loss: 9.8801 - gender_loss: 0.3980 - age_mae: 9.8801 - gender_accuracy: 0.8155 - val_loss: 9.5648 - val_age_loss: 9.1802 - val_gender_loss: 0.3847 - val_age_mae: 9.1802 - val_gender_accuracy: 0.8419
# Epoch 24/30
# 173/173 [==============================] - 514s 3s/step - loss: 10.1180 - age_loss: 9.7376 - gender_loss: 0.3804 - age_mae: 9.7376 - gender_accuracy: 0.8196 - val_loss: 9.9250 - val_age_loss: 9.5658 - val_gender_loss: 0.3592 - val_age_mae: 9.5658 - val_gender_accuracy: 0.8470
# Epoch 25/30
# 173/173 [==============================] - 497s 3s/step - loss: 9.9600 - age_loss: 9.5761 - gender_loss: 0.3839 - age_mae: 9.5761 - gender_accuracy: 0.8194 - val_loss: 9.8431 - val_age_loss: 9.4913 - val_gender_loss: 0.3518 - val_age_mae: 9.4913 - val_gender_accuracy: 0.8512
# Epoch 26/30
# 173/173 [==============================] - 590s 3s/step - loss: 10.0649 - age_loss: 9.6849 - gender_loss: 0.3800 - age_mae: 9.6849 - gender_accuracy: 0.8251 - val_loss: 8.9675 - val_age_loss: 8.6058 - val_gender_loss: 0.3617 - val_age_mae: 8.6058 - val_gender_accuracy: 0.8360
# Epoch 27/30
# 173/173 [==============================] - 505s 3s/step - loss: 9.9285 - age_loss: 9.5496 - gender_loss: 0.3790 - age_mae: 9.5496 - gender_accuracy: 0.8271 - val_loss: 9.1470 - val_age_loss: 8.8035 - val_gender_loss: 0.3435 - val_age_mae: 8.8035 - val_gender_accuracy: 0.8588
# Epoch 28/30
# 173/173 [==============================] - 545s 3s/step - loss: 9.6464 - age_loss: 9.2740 - gender_loss: 0.3724 - age_mae: 9.2740 - gender_accuracy: 0.8285 - val_loss: 9.0683 - val_age_loss: 8.7248 - val_gender_loss: 0.3435 - val_age_mae: 8.7248 - val_gender_accuracy: 0.8487
# Epoch 29/30
# 173/173 [==============================] - 517s 3s/step - loss: 9.6576 - age_loss: 9.2953 - gender_loss: 0.3623 - age_mae: 9.2953 - gender_accuracy: 0.8390 - val_loss: 8.9879 - val_age_loss: 8.6479 - val_gender_loss: 0.3400 - val_age_mae: 8.6479 - val_gender_accuracy: 0.8597
# Epoch 30/30
# 173/173 [==============================] - 582s 3s/step - loss: 9.4647 - age_loss: 9.0975 - gender_loss: 0.3672 - age_mae: 9.0975 - gender_accuracy: 0.8287 - val_loss: 8.9635 - val_age_loss: 8.5946 - val_gender_loss: 0.3689 - val_age_mae: 8.5946 - val_gender_accuracy: 0.8335

# %%
import pickle

# Menyimpan history ke file
with open('history_cnn.pkl', 'wb') as file:
    pickle.dump(history.history, file)

# %%
# Save model in h5 format
model.save('./models/model_cnn.h5')

# Save model in pb format
model.save('./models/model_cnn')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/model_cnn\assets
# INFO:tensorflow:Assets written to: ./models/model_cnn\assets

# %%
import matplotlib.pyplot as plt

# Plot Age Mean Absolute Error (MAE)
plt.figure(figsize=(8, 4))
plt.plot(history.history['age_mae'], label='Train Age MAE')
plt.plot(history.history['val_age_mae'], label='Validation Age MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid()
plt.show()

# Plot Gender Accuracy
plt.figure(figsize=(8, 4))
plt.plot(history.history['gender_accuracy'], label='Train Gender Accuracy')
plt.plot(history.history['val_gender_accuracy'], label='Validation Gender Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# Model evaluation on the test dataset
test_loss, test_age_loss, test_gender_loss, test_age_mae, test_gender_accuracy  = model.evaluate(test_ds)
print('Test loss:', test_loss)
print('Test Gender Loss:', test_gender_loss)
print('Test Age Loss:', test_age_loss)
print('Test Gender Accuracy:', test_gender_accuracy)
print('Test Age MAE:', test_age_mae)
# Out:
# 37/37 [==============================] - 27s 709ms/step - loss: 9.2373 - age_loss: 8.9017 - gender_loss: 0.3356 - age_mae: 8.9017 - gender_accuracy: 0.8463
# Test loss: 9.237285614013672
# Test Gender Loss: 0.33558449149131775
# Test Age Loss: 8.901700973510742
# Test Gender Accuracy: 0.8462837934494019
# Test Age MAE: 8.901700973510742

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Ambil batch acak dari test_ds
for images, labels in test_ds.take(1):
    batch_size = images.shape[0]
    random_indices = random.sample(range(batch_size), 5)
    random_images = images.numpy()[random_indices]

    # Memisahkan age dan gender dari labels
    ages = labels[0].numpy()[random_indices]
    genders = labels[1].numpy()[random_indices]

    # Lakukan prediksi
    predictions = model.predict(random_images)
    pred_ages = predictions[0].flatten()
    pred_genders = predictions[1].flatten()

    # Plot gambar dan prediksi
    plt.figure(figsize=(15, 15))
    for i in range(5):
        true_age = ages[i]
        true_gender = 'Male' if genders[i] == 0 else 'Female'
        pred_age = int(pred_ages[i])
        pred_gender = 'Male' if pred_genders[i] < 0.5 else 'Female'
        gender_confidence = 1 - pred_genders[i] if pred_genders[i] < 0.5 else pred_genders[i]

        plt.subplot(1, 5, i + 1)
        plt.imshow(random_images[i])
        plt.title(f"True Age: {true_age}\nTrue Gender: {true_gender}\n"
                  f"Pred Age: {pred_age}\nPred Gender: {pred_gender}\n"
                  f"Confidence: {gender_confidence:.2f}")
        plt.axis('off')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 148ms/step

# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# Ambil batch acak dari test_ds
for images, labels in test_ds.take(1):
    batch_size = images.shape[0]
    random_indices = random.sample(range(batch_size), 5)
    random_images = images.numpy()[random_indices]

    # Memisahkan age dan gender dari labels
    ages = labels[0].numpy()[random_indices]
    genders = labels[1].numpy()[random_indices]

    # Lakukan prediksi
    predictions = model.predict(random_images)
    pred_ages = predictions[0].flatten()
    pred_genders = predictions[1].flatten()

    # Plot gambar dan prediksi
    plt.figure(figsize=(15, 15))
    for i in range(5):
        true_age = ages[i]
        true_gender = 'Male' if genders[i] == 0 else 'Female'
        pred_age = int(pred_ages[i])
        pred_gender = 'Male' if pred_genders[i] < 0.5 else 'Female'
        gender_confidence = 1 - pred_genders[i] if pred_genders[i] < 0.5 else pred_genders[i]

        plt.subplot(1, 5, i + 1)
        plt.imshow(random_images[i])
        plt.title(f"True Age: {true_age}\nTrue Gender: {true_gender}\n"
                  f"Pred Age: {pred_age}\nPred Gender: {pred_gender}\n"
                  f"Confidence: {gender_confidence:.2f}")
        plt.axis('off')
    plt.show()
# Out:
# 1/1 [==============================] - 0s 139ms/step

# %%
import tensorflow as tf

def predict_uploaded_image(image_path):
    # Baca dan preprocess gambar
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (200, 200))
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.expand_dims(image, axis=0)  # Tambahkan batch dimension

    # Lakukan prediksi
    predictions = model.predict(image)
    pred_age = int(predictions[0].flatten()[0])
    pred_gender_prob = predictions[1].flatten()[0]
    pred_gender = 'Male' if pred_gender_prob < 0.5 else 'Female'
    gender_confidence = 1 - pred_gender_prob if pred_gender_prob < 0.5 else pred_gender_prob

    # Tampilkan gambar dan hasil prediksi
    plt.imshow(tf.squeeze(image))
    plt.title(f"Predicted Age: {pred_age}\nPredicted Gender: {pred_gender}\nConfidence: {gender_confidence:.2f}")
    plt.axis('off')
    plt.show()

# Contoh penggunaan, ganti 'path_to_your_image.jpg' dengan path gambar yang ingin diunggah
predict_uploaded_image('Muhammad Nugraha Mahardhika - Blue Edited.jpg')
# Out:
# 1/1 [==============================] - 0s 93ms/step
