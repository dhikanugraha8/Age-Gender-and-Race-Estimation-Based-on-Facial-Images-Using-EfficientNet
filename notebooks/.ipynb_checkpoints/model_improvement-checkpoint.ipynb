# %%
import os
import re
import random
import matplotlib.pyplot as plt
import numpy as np
from collections import Counter
import tensorflow as tf
from tensorflow.keras import Input, Model, layers
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.losses import Huber

# Regular expression to parse the filename
dataset_path ='../data'
pattern = r"(\d+)_(\d)_(\d)_(\d+).jpg"

# Fungsi untuk mengurai label dari nama file
def parse_label(filename):
    match = re.match(pattern, filename)
    if match:
        age = int(match.group(1))
        gender = int(match.group(2))
        race = int(match.group(3))
        return age, gender, race
    else:
        raise ValueError(f"Filename {filename} tidak sesuai format")

# Fungsi untuk plot distribusi data berdasarkan label
def plot_distribution(files):
    ages = [parse_label(os.path.basename(f))[0] for f in files]  # Umur
    genders = [parse_label(os.path.basename(f))[1] for f in files]  # Gender
    races = [parse_label(os.path.basename(f))[2] for f in files]  # Race

    # Plot distribusi age
    plt.figure(figsize=(8, 5))
    plt.hist(ages, bins=24, color='yellow', edgecolor='black')
    plt.title('Age Distribution in Dataset (Before Downsampling)')
    plt.xlabel('Age')
    plt.ylabel('Frequency')
    plt.show()

    # Plot distribusi gender
    plt.figure(figsize=(8, 5))
    gender_counts = Counter(genders)
    plt.bar(gender_counts.keys(), gender_counts.values(), color=['blue', 'pink'])
    plt.xticks([0, 1], ['Male', 'Female'])
    plt.title('Gender Distribution in Dataset (Before Downsampling)')
    plt.xlabel('Gender')
    plt.ylabel('Count')
    plt.show()

    # Plot distribusi race
    plt.figure(figsize=(8, 5))
    race_counts = Counter(races)
    plt.bar(race_counts.keys(), race_counts.values(), color=['gray', 'black', 'yellow', 'red', 'green'])
    plt.xticks([0, 1, 2, 3, 4], ['White', 'Black', 'Asian', 'Indian', 'Others'])
    plt.title('Race Distribution in Dataset (Before Downsampling)')
    plt.xlabel('Race')
    plt.ylabel('Count')
    plt.show()

# Get all image files
all_files = [os.path.join(dataset_path, f) for f in os.listdir(dataset_path) if f.endswith('.jpg')]

# Panggil fungsi untuk menampilkan distribusi awal
plot_distribution(all_files)

# %%
import numpy as np
import random
import os
import re
import matplotlib.pyplot as plt

# Fungsi untuk melakukan stratified downsampling berdasarkan usia dengan pertimbangan ras
def stratified_downsample_by_age(files, age_bins, target_per_bin=1000):
    race_white = 0  # race 'White' diwakili oleh 0
    age_to_files = {i: [] for i in range(len(age_bins) - 1)}  # Buat dictionary untuk setiap bin usia

    # Pisahkan file berdasarkan rentang usia
    for f in files:
        age, _, race = parse_label(os.path.basename(f))
        for i in range(len(age_bins) - 1):
            if age_bins[i] <= age < age_bins[i + 1]:
                age_to_files[i].append((f, race))  # Simpan file dan race
                break

    # List baru untuk menyimpan file setelah downsampling
    selected_files = []
    for age_bin_idx, age_bin_files in age_to_files.items():
        if len(age_bin_files) > target_per_bin:
            # Lakukan downsampling secara proporsional
            white_files = [f for f, race in age_bin_files if race == race_white]
            non_white_files = [f for f, race in age_bin_files if race != race_white]

            if len(white_files) > target_per_bin:
                selected_files.extend(random.sample(white_files, target_per_bin))
            else:
                selected_files.extend(white_files)
                remaining_needed = target_per_bin - len(white_files)
                selected_files.extend(random.sample(non_white_files, remaining_needed))
        else:
            selected_files.extend([f for f, _ in age_bin_files])

    return selected_files

# Path dataset (ubah sesuai lokasi dataset)
dataset_path = '../data'

# Tentukan rentang usia untuk bins
age_bins = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50, 60, 70, 80, 90, 100]  # Rentang usia

# Lakukan downsampling
downsampled_files = stratified_downsample_by_age(all_files, age_bins, target_per_bin=1000)

# Call the function to visualize the distribution of age, race, and gender after downsampling
plot_distribution(downsampled_files)

# %%
# Define image and batch size 
image_size = (200, 200)
batch_size = 32

# Regular expression to parse the filename
pattern = r"(\d+)_(\d)_(\d)_(\d+).jpg"

# Function to parse the label from the filename
def parse_label(filename):
    match = re.match(pattern, filename)
    if match:
        age = int(match.group(1))
        gender = int(match.group(2))
        race = int(match.group(3))
        return age, gender, race
    else:
        raise ValueError(f"Filename {filename} does not match the format")

# Function to load image and label
def load_image(filename, label):
    image = tf.io.read_file(filename)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, image_size)
    image = tf.cast(image, tf.float32) / 255.0
    
    age, gender, race = label
    return image, (age, gender, race)

# Function to create a dataset from image files
def create_dataset(image_files):
    labels = [parse_label(os.path.basename(file)) for file in image_files]
    ages = tf.constant([label[0] for label in labels], dtype=tf.int32)
    genders = tf.constant([label[1] for label in labels], dtype=tf.int32)
    races = tf.constant([label[2] for label in labels], dtype=tf.int32)

    dataset = tf.data.Dataset.from_tensor_slices((image_files, (ages, genders, races)))
    dataset = dataset.map(lambda x, y: (load_image(x, y)), num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
# Get all image files
total_files = len(downsampled_files)

# Shuffle files with a consistent seed
seed = 42
random.seed(seed)
random.shuffle(downsampled_files)

# Split the data into train, validation, and test
train_split = 0.5
val_split = 0.25
test_split = 0.25

train_count = int(total_files * train_split)
val_count = int(total_files * val_split)

train_files = downsampled_files[:train_count]
val_files = downsampled_files[train_count:train_count + val_count]
test_files = downsampled_files[train_count + val_count:]

# Create dataset for each subset
train_ds = create_dataset(train_files)
val_ds = create_dataset(val_files)
test_ds = create_dataset(test_files)

# %%
# Function to show image samples and labels for age, gender, and race
def show_image_samples(dataset, subset_name, num_samples=5):
    plt.figure(figsize=(20, 6))
    gender_map = {0: 'Male', 1: 'Female'}
    race_map = {0: 'White', 1: 'Black', 2: 'Asian', 3: 'Indian', 4: 'Others'}
    
    for images, (ages, genders, races) in dataset.take(1):
        for j in range(num_samples):
            ax = plt.subplot(1, num_samples, j + 1)
            plt.imshow(images[j].numpy())
            age = ages[j].numpy()
            gender = genders[j].numpy()
            race = races[j].numpy()
            plt.title(f"Age: {age}\n Gender: {gender_map[gender]} \n Race: {race_map[race]}", fontsize=100/num_samples)
            plt.axis("off")
    
    plt.suptitle(f"{subset_name} Samples", fontsize=20)
    plt.show()
    print('\n')

# Display some image samples and labels from each subset
show_image_samples(train_ds, "Training",)
show_image_samples(val_ds, "Validation")
show_image_samples(test_ds, "Testing")

# %%
# Function to plot the age distribution
def plot_age_distribution(dataset, subset_name):
    ages = []
    for _, (age_labels, _, _) in dataset:
        ages.extend(age_labels.numpy())
    
    plt.figure(figsize=(6, 4))
    plt.hist(ages, bins=range(0, 120, 5), edgecolor='black')
    plt.title(f"Age Distribution in {subset_name} Set")
    plt.xlabel("Age")
    plt.ylabel("Frequency")
    plt.show()

# Plot age distributions for training, validation, and test sets
plot_age_distribution(train_ds, "Training")
plot_age_distribution(val_ds, "Validation")
plot_age_distribution(test_ds, "Testing")

# %%
# Function to plot the gender distribution
def plot_gender_distribution(dataset, subset_name):
    gender_count = {0: 0, 1: 0}
    for _, (_, gender_labels, _) in dataset:
        unique, counts = np.unique(gender_labels.numpy(), return_counts=True)
        for u, c in zip(unique, counts):
            gender_count[u] += c
    
    plt.figure(figsize=(6, 4))
    plt.bar(['Male', 'Female'], [gender_count[0], gender_count[1]], color=['blue', 'pink'])
    plt.title(f"Gender Distribution in {subset_name} Set")
    plt.xlabel("Gender")
    plt.ylabel("Count")
    plt.show()

# Plot gender distributions for training, validation, and test sets
plot_gender_distribution(train_ds, "Training")
plot_gender_distribution(val_ds, "Validation")
plot_gender_distribution(test_ds, "Testing")

# %%
# Function to plot the race distribution
def plot_race_distribution(dataset, subset_name):
    race_count = {0: 0, 1: 0, 2: 0, 3: 0, 4: 0}
    for _, (_, _, race_labels) in dataset:
        unique, counts = np.unique(race_labels.numpy(), return_counts=True)
        for u, c in zip(unique, counts):
            race_count[u] += c
    
    plt.figure(figsize=(6, 4))
    plt.bar(['White', 'Black', 'Asian', 'Indian', 'Others'], 
            [race_count[i] for i in range(5)], color=['gray', 'black', 'yellow', 'brown', 'green'])
    plt.title(f"Race Distribution in {subset_name} Set")
    plt.xlabel("Race")
    plt.ylabel("Count")
    plt.show()

# Plot race distributions for training, validation, and test sets
plot_race_distribution(train_ds, "Training")
plot_race_distribution(val_ds, "Validation")
plot_race_distribution(test_ds, "Testing")

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomContrast(0.1),
    layers.RandomBrightness(0.2)
])

# %%
# Create Model
input_shape = (200, 200, 3)  # sesuai input shape
inputs = Input(input_shape)

# Convolutional layers
inputs = Input(shape=input_shape)
# x = data_augmentation(inputs) 
x = layers.Conv2D(32, kernel_size=(5, 5), activation='relu')(x) 
x = layers.Conv2D(64, kernel_size=(3, 3), strides=(2, 2), activation='relu')(x)
x = layers.Conv2D(128, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(256, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Conv2D(512, kernel_size=(3, 3), activation='relu')(x)
x = layers.MaxPooling2D(pool_size=(2, 2))(x)

x = layers.Flatten()(x)

# Dense layers for each output
dense_age = layers.Dense(256, activation='relu')(x)
dropout_age = layers.Dropout(0.2)(dense_age)
age = layers.Dense(1, activation='relu', name='age')(dropout_age)

dense_gender = layers.Dense(256, activation='relu')(x)
dropout_gender = layers.Dropout(0.2)(dense_gender)
gender = layers.Dense(1, activation='sigmoid', name='gender')(dropout_gender)

dense_race = layers.Dense(256, activation='relu')(x)
dropout_race = layers.Dropout(0.2)(dense_race)
race = layers.Dense(5, activation='softmax', name='race')(dropout_race)

# %%
# Model with two outputs
model = Model(inputs=inputs, outputs=[age,gender,race])

huber_loss = Huber()
model.compile(
    optimizer='adam',
    loss={'age': huber_loss, 'gender': 'binary_crossentropy', 'race': 'sparse_categorical_crossentropy'},
    metrics={'age': 'mae', 'gender': 'accuracy', 'race': 'accuracy'}
)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 200, 200, 3  0           []
#                                 )]
#
#  sequential (Sequential)        (None, 200, 200, 3)  0           ['input_6[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 196, 196, 32  2432        ['sequential[2][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 97, 97, 64)   18496       ['conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 95, 95, 128)  73856       ['conv2d_11[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 47, 47, 128)  0          ['conv2d_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 45, 45, 256)  295168      ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 22, 22, 256)  0          ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 20, 20, 512)  1180160     ['max_pooling2d_7[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 10, 10, 512)  0          ['conv2d_14[0][0]']
#
#  flatten_2 (Flatten)            (None, 51200)        0           ['max_pooling2d_8[0][0]']
#
#  dense_6 (Dense)                (None, 256)          13107456    ['flatten_2[0][0]']
#
#  dense_7 (Dense)                (None, 256)          13107456    ['flatten_2[0][0]']
#
#  dense_8 (Dense)                (None, 256)          13107456    ['flatten_2[0][0]']
#
#  dropout_6 (Dropout)            (None, 256)          0           ['dense_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 256)          0           ['dense_7[0][0]']
#
#  dropout_8 (Dropout)            (None, 256)          0           ['dense_8[0][0]']
#
#  age (Dense)                    (None, 1)            257         ['dropout_6[0][0]']
#
#  gender (Dense)                 (None, 1)            257         ['dropout_7[0][0]']
#
#  race (Dense)                   (None, 5)            1285        ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 40,894,279
# Trainable params: 40,894,279
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5,          
    restore_best_weights=True 
)

# Model fitting
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=30,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# 200/200 [==============================] - 1983s 10s/step - loss: 23.3888 - age_loss: 21.0883 - gender_loss: 0.9624 - race_loss: 1.3381 - age_mae: 21.5834 - gender_accuracy: 0.5164 - race_accuracy: 0.7202 - val_loss: 20.3291 - val_age_loss: 18.6544 - val_gender_loss: 0.6925 - val_race_loss: 0.9822 - val_age_mae: 19.1494 - val_gender_accuracy: 0.5469 - val_race_accuracy: 0.7227
# Epoch 2/30
# 200/200 [==============================] - 1952s 10s/step - loss: 19.9453 - age_loss: 18.2814 - gender_loss: 0.6923 - race_loss: 0.9716 - age_mae: 18.7762 - gender_accuracy: 0.5297 - race_accuracy: 0.7318 - val_loss: 20.3757 - val_age_loss: 18.6988 - val_gender_loss: 0.6909 - val_race_loss: 0.9861 - val_age_mae: 19.1950 - val_gender_accuracy: 0.5469 - val_race_accuracy: 0.7227
# Epoch 3/30
# 200/200 [==============================] - 1911s 10s/step - loss: 19.8964 - age_loss: 18.2381 - gender_loss: 0.6917 - race_loss: 0.9665 - age_mae: 18.7322 - gender_accuracy: 0.5295 - race_accuracy: 0.7318 - val_loss: 20.4239 - val_age_loss: 18.7565 - val_gender_loss: 0.6902 - val_race_loss: 0.9772 - val_age_mae: 19.2518 - val_gender_accuracy: 0.5469 - val_race_accuracy: 0.7227
# Epoch 4/30
# 200/200 [==============================] - 1767s 9s/step - loss: 20.7913 - age_loss: 19.0949 - gender_loss: 0.6964 - race_loss: 1.0000 - age_mae: 19.5904 - gender_accuracy: 0.5308 - race_accuracy: 0.7291 - val_loss: 20.4151 - val_age_loss: 18.7342 - val_gender_loss: 0.6900 - val_race_loss: 0.9909 - val_age_mae: 19.2306 - val_gender_accuracy: 0.5469 - val_race_accuracy: 0.7227
# Epoch 5/30
# 149/200 [=====================>........] - ETA: 6:05 - loss: 19.8927 - age_loss: 18.2340 - gender_loss: 0.6913 - race_loss: 0.9674 - age_mae: 18.7276 - gender_accuracy: 0.5317 - race_accuracy: 0.7318
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [20], in <cell line: 9>()
#       2 early_stopping = EarlyStopping(
#       3     monitor='val_loss',
#       4     patience=5,
#       5     restore_best_weights=True
#       6 )
#       8 # Model fitting
# ----> 9 history = model.fit(
#      10     train_ds,
#      11     validation_data=val_ds,
#      12     epochs=30,
#      13     callbacks=[early_stopping]
#      14 )
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\utils\traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\keras\engine\training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File ~\AppData\Local\Programs\Python\Python38\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
import pickle

# Menyimpan history ke file
with open('history_3_ds.pkl', 'wb') as file:
    pickle.dump(history.history, file)

# %%
# Save model in h5 format
model.save('./models/model_cnn_3_ds.h5')

# Save model in pb format
model.save('./models/model_cnn_3_ds')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 4 of 4). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./models/model_cnn_3_ds\assets
# INFO:tensorflow:Assets written to: ./models/model_cnn_3_ds\assets

# %%
from tensorflow.keras.models import load_model

# Memuat model yang sudah dilatih 30 epoch
model = load_model('./models/model_cnn_3_ds.h5')

import pickle

# Memuat kembali history dari file
with open('history_3_ds.pkl', 'rb') as file:
    history = pickle.load(file)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting Bitcast
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformFullIntV2
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomGetKeyCounter
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2
# WARNING:tensorflow:Using a while_loop for converting AdjustContrastv2

# %%
# Plot evaluation metrics for age, gender, and race
plt.figure(figsize=(8, 4))
plt.plot(history.history['age_mae'], label='Train Age MAE')
plt.plot(history.history['val_age_mae'], label='Validation Age MAE')
plt.title('Age Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(history.history['gender_accuracy'], label='Train Gender Accuracy')
plt.plot(history.history['val_gender_accuracy'], label='Validation Gender Accuracy')
plt.title('Gender Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

plt.figure(figsize=(8, 4))
plt.plot(history.history['race_accuracy'], label='Train Race Accuracy')
plt.plot(history.history['val_race_accuracy'], label='Validation Race Accuracy')
plt.title('Race Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid()
plt.show()

# %%
# Evaluate on the test dataset
test_loss, test_age_loss, test_gender_loss, test_race_loss, test_age_mae, test_gender_accuracy, test_race_accuracy = model.evaluate(test_ds)
print('Test Gender Accuracy:', test_gender_accuracy)
print('Test Race Accuracy:', test_race_accuracy)
print('Test Age MAE:', test_age_mae)
# Out:
# 100/100 [==============================] - 67s 670ms/step - loss: 118.2486 - age_loss: 117.2721 - gender_loss: 0.3232 - race_loss: 0.6532 - age_mae: 8.1375 - gender_accuracy: 0.8587 - race_accuracy: 0.7751
# Test Gender Accuracy: 0.8587092757225037
# Test Race Accuracy: 0.7750626802444458
# Test Age MAE: 8.13748836517334

# %%
import matplotlib.pyplot as plt
import random

# Ambil batch acak dari test_ds
for images, labels in test_ds.take(1):
    batch_size = images.shape[0]
    random_indices = random.sample(range(batch_size), 5)
    random_images = images.numpy()[random_indices]

    # Memisahkan age, gender, dan race dari labels
    ages = labels[0].numpy()[random_indices]
    genders = labels[1].numpy()[random_indices]
    races = labels[2].numpy()[random_indices]

    # Lakukan prediksi
    predictions = model.predict(random_images)
    pred_ages = predictions[0].flatten()
    pred_genders = predictions[1].flatten()
    pred_races = predictions[2].argmax(axis=1)
    pred_race_confidences = predictions[2].max(axis=1)

    # Plot gambar dan prediksi
    plt.figure(figsize=(15, 15))
    for i in range(5):
        true_age = ages[i]
        true_gender = 'Male' if genders[i] == 0 else 'Female'
        true_race = ['White', 'Black', 'Asian', 'Indian', 'Others'][races[i]]

        pred_age = int(pred_ages[i])
        pred_gender = 'Male' if pred_genders[i] < 0.5 else 'Female'
        gender_confidence = 1 - pred_genders[i] if pred_genders[i] < 0.5 else pred_genders[i]
        pred_race = ['White', 'Black', 'Asian', 'Indian', 'Others'][pred_races[i]]
        race_confidence = pred_race_confidences[i]

        plt.subplot(1, 5, i + 1)
        plt.imshow(random_images[i])
        plt.title(f"Age: {true_age}\nGender: {true_gender}\nRace: {true_race}")
        plt.axis('off')  # Menghilangkan penggaris pixel
        
        # Tambahkan label di bawah gambar menggunakan plt.text
        plt.text(0.5, -0.1, 
                 f"Age Pred: {pred_age}\nGender Pred: {pred_gender} ({gender_confidence:.2f})\nRace Pred: {pred_race} ({race_confidence:.2f})",
                 fontsize=12, ha='center', va='top', transform=plt.gca().transAxes)

    plt.show()
# Out:
# 1/1 [==============================] - 0s 161ms/step

# %%
def predict_uploaded_image(image_path):
    # Baca dan preprocess gambar
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, (200, 200))
    image = tf.cast(image, tf.float32) / 255.0
    image = tf.expand_dims(image, axis=0)  # Tambahkan batch dimension

    # Lakukan prediksi
    predictions = model.predict(image)
    pred_age = int(predictions[0].flatten()[0])
    pred_gender_prob = predictions[1].flatten()[0]
    pred_gender = 'Male' if pred_gender_prob < 0.5 else 'Female'
    gender_confidence = 1 - pred_gender_prob if pred_gender_prob < 0.5 else pred_gender_prob

    pred_race_probs = tf.nn.softmax(predictions[2], axis=1).numpy()
    pred_race_index = pred_race_probs[0].argmax()
    race_labels = ['White', 'Black', 'Asian', 'Indian', 'Others']
    pred_race = race_labels[pred_race_index]
    race_confidence = pred_race_probs[0][pred_race_index]

    # Tampilkan gambar dan hasil prediksi
    plt.imshow(tf.squeeze(image))
    plt.title(f"Age Pred: {pred_age}\nGender Pred: {pred_gender} ({gender_confidence:.2f})\n"
              f"Race Pred: {pred_race} ({race_confidence:.2f})")
    plt.axis('off')
    plt.show()

# Contoh penggunaan, ganti 'path_to_your_image.jpg' dengan path gambar yang ingin diunggah
predict_uploaded_image('../asset/image_3.jpg')
# Out:
# 1/1 [==============================] - 0s 64ms/step
